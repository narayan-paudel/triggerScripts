# %%
import numpy as np
import pandas as pd

# %%
slcVEM = pd.read_hdf(str("/home/enpaudel/icecube/triggerStudy/simFiles/dataSetCleanTest/pDAT000016GenDetFiltProcUniqueCleanVEMEvts.hdf5"),key="OfflineIceTopSLCVEMPulses")

# %%
slcVEM
# Out:
#      Run  Event  SubEvent  SubEventStream  exists  string  om  pmt  \
# 0     16  16100         0               0       1      10  63    0
# 1     16  16100         0               0       1      21  63    0
# 2     16  16100         0               0       1      30  63    0
# 3     16  16100         0               0       1      36  63    0
# 4     16  16100         0               0       1      38  61    0
# ..   ...    ...       ...             ...     ...     ...  ..  ...
# 393   16  16199         0               0       1      24  61    0
# 394   16  16199         0               0       1      34  63    0
# 395   16  16199         0               0       1      48  63    0
# 396   16  16199         0               0       1      57  61    0
# 397   16  16199         0               0       1      68  61    0
#
#      vector_index      time  width    charge
# 0               0  582475.0  512.0  0.247604
# 1               0  583006.0  512.0  0.213250
# ...

# %%
slcVEM["time"].values
# Out:
# array([582475., 583006., 583420., 583545., 583455., 583916., 583342.,
#        583994., 584060., 584186., 583774., 583837., 584551., 581613.,
#        581878., 582662., 582957., 583441., 583182., 583516., 583702.,
#        583833., 583302., 583822., 584361., 581325., 584350., 584549.,
#        581552., 583061., 583091., 583148., 583280., 583871., 584783.,
#        582266., 582590., 583215., 583635., 583639., 581496., 581346.,
#        582250., 585113., 583221., 583903., 584446., 581370., 582273.,
#        582677., 581274., 581565., 582462., 582580., 583272., 583167.,
#        583283., 583480., 583880., 584411., 584549., 586488., 582023.,
#        582128., 582240., 582494., 583366., 583350., 583632., 583726.,
#        583458., 582393., 584754., 583048., 583221., 583749., 584161.,
#        584292., 583863., 583912., 585618., 585562., 585828., 584027.,
#        583956., 584099., 584219., 584350., 584239., 584588., 584823.,
# ...
